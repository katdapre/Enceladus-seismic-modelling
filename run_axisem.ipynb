# %% [markdown]
# This notebook runs the original, one-dimensional AxiSEM code (https://github.com/geodynamics/axisem) from start to finish.
#
# Everything it does could also be done simply on the command line, but I found this a useful way to automate/centralise input parameters and make the process less fiddly early in my PhD.
#
# You should only need to edit the parameters in the second cell, provided you follow the AxiSEM file structure and have pointed the notebook to the mesher and solver directories.

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp
from subprocess import run
import re

# %% [markdown]
# Manually set variables and path names - edit this cell!

# %%
### inparam_mesh ###
#background model e.g. prem_iso, ak135, iasp91, external
bg_model = 'external'
ext_model = "github_ice_shell.bm"
dom_period ='0.5'
#FSF = 0.9
radius = '2.52e+5'#m
c_layers = '0'

### inparam_basic ###
#sim_type e.g. single, moment, force
sim_type = 'single'
duration = '200' #s
#rec_type e.g. colatlon or stations
rec_type = 'colatlon'
run_name = 'github_2Hz_test13'

lat_hetero = 'False'
attenuation = 'False'
save_snapshots = 'False'

### inparam_source ###
#source type e.g. mrr, explosion, mtt_p_mpp, vertforce | mtr, mpr, thetaforce, phiforce | mtp, mtt_m_mpp
source_type = 'mrr'
source_dep = '5.0'
ev_lat = '90.0'
ev_lon = '0.0'
source_amp = '1E13'

### inparam_advanced ###
#source function e.g. errorf, gauss_0, gauss_1, gauss_2, quheavi, dirac_0
source_function = 'gauss_0'
# only relevant if save_snapshots = true
snapshot_dt = '5.'
snapshots_format = 'vtk'
# ATTENUATION
f_min = '0.01'
f_max = '10'
f_ref = '1.0'

### CMTSOLUTION ###
#takes source_dep, ev_lat, and ev_lon in the case that sim_type = 'moment'
Mrr = '4.710000e+24'
Mtt = '3.810000e+22'
Mpp = '-4.740000e+24'
Mrt = '3.990000e+23'
Mrp = '-8.050000e+23'
Mtp = '-1.230000e+24'

### let python know where the MESHER and SOLVER directories are ###
MESHER = "./axisem-code/MESHER"
SOLVER = "./axisem-code/SOLVER"

# %% [markdown]
# Implement all those variables

# %%
with open(f"{MESHER}/inparam_mesh", 'r') as fin:
    file = fin.read()
    #lines represents the full text of the original file
    lines = file.splitlines()
    #check every line in turn for the text:
    for i in range(0, len(lines)):
        if 'BACKGROUND_MODEL' in lines[i]:
            p = lines[i].split()
            #replace the second entry on the line with the new background model
            lines[i] = lines[i].replace(p[1], bg_model)
        if 'EXT_MODEL' in lines[i] and 'external:' not in lines[i]:
            if ext_model is not None:
                lines[i] = f"EXT_MODEL           {ext_model}"
                print(lines[i])
            if ext_model is None:
                lines[i] = f"# EXT_MODEL           {ext_model}"
                print(lines[i])
        if 'DOMINANT_PERIOD' in lines[i]:
            p = lines[i].split()
            lines[i] = lines[i].replace(p[1], dom_period)
        if 'COARSENING_LAYERS' in lines[i]:
            p = lines[i].split()
            lines[i] = lines[i].replace(p[1], c_layers)
        #if 'FLUID_SHRINKING_FACTOR' in lines[i]:
            #p = lines[i].split()
            #lines[i] = lines[i].replace(p[1], FSF) 
        if 'RADIUS' in lines[i]:
            lines[i] = f"RADIUS             {radius}"

#opens writable file to output updated text; individually writes each line in turn
with open(f"{MESHER}/inparam_mesh", 'w') as fout:
    for item in lines:
        fout.write("%s\n" % item)
# Out:
# EXT_MODEL           github_ice_shell.bm

# %%
with open(f"{SOLVER}/inparam_basic", 'r') as fin:
    file2 = fin.read()
    lines2 = file2.splitlines()
    for i in range(0, len(lines2)):
        if 'SIMULATION_TYPE' in lines2[i]:
            p = lines2[i].split()
            lines2[i] = lines2[i].replace(p[1], sim_type)
        if 'SEISMOGRAM_LENGTH' in lines2[i]:
            p = lines2[i].split()
            lines2[i] = lines2[i].replace(p[1], duration)
        if 'RECFILE_TYPE' in lines2[i]:
            p = lines2[i].split()
            lines2[i] = lines2[i].replace(p[1], rec_type) 
        if 'MESHNAME' in lines2[i]:
            p = lines2[i].split()
            lines2[i] = lines2[i].replace(p[1],run_name)
        if 'LAT_HETEROGENEITY' in lines2[i]:
            p = lines2[i].split()
            lines2[i] = lines2[i].replace(p[1], lat_hetero)
        if 'ATTENUATION' in lines2[i]:
            p = lines2[i].split()
            lines2[i] = lines2[i].replace(p[1], attenuation)
        if 'SAVE_SNAPSHOTS' in lines2[i]:
            p = lines2[i].split()
            lines2[i] = lines2[i].replace(p[1], save_snapshots)
            
with open(f"{SOLVER}/inparam_basic", 'w') as fout:
    for item in lines2:
        fout.write("%s\n" % item)

if sim_type == 'moment':
    with open (f"{SOLVER}/CMTSOLUTION", 'r') as fin:
        file4 = fin.read()
        lines4 = file4.splitlines()
        for i in range(0, len(lines4)):
            if 'latitude' in lines4[i]:
                print(lines4[i])
                p = lines4[i].split(":")
                lines4[i] = lines4[i].replace(p[1].strip(), ev_lat)
                print(lines4[i])
            if 'longitude' in lines4[i]:
                p = lines4[i].split(":")
                lines4[i] = lines4[i].replace(p[1].strip(), ev_lon)
            if 'depth' in lines4[i]:
                p = lines4[i].split(":")
                lines4[i] = lines4[i].replace(p[1].strip(), source_dep)
            if 'Mrr' in lines4[i]:
                p = lines4[i].split(":")
                lines4[i] = lines4[i].replace(p[1].strip(), Mrr)
            if 'Mtt' in lines4[i]:
                p = lines4[i].split(":")
                lines4[i] = lines4[i].replace(p[1].strip(), Mtt)
            if 'Mpp' in lines4[i]:
                p = lines4[i].split(":")
                lines4[i] = lines4[i].replace(p[1].strip(), Mpp)
            if 'Mrt' in lines4[i]:
                p = lines4[i].split(":")
                lines4[i] = lines4[i].replace(p[1].strip(), Mrt)
            if 'Mrp' in lines4[i]:
                p = lines4[i].split(":")
                lines4[i] = lines4[i].replace(p[1].strip(), Mrp)
            if 'Mtp' in lines4[i]:
                p = lines4[i].split(":")
                lines4[i] = lines4[i].replace(p[1].strip(), Mtp)
                
    with open(f"{SOLVER}/CMTSOLUTION", 'w') as fout:
        for item in lines4:
            fout.write("%s\n" % item)
        
with open(f"{SOLVER}/inparam_source", 'r') as fin:
    file3 = fin.read()
    lines3 = file3.splitlines()
    for i in range(0, len(lines3)):
        if 'SOURCE_TYPE' in lines3[i]:
            p = lines3[i].split()
            lines3[i] = lines3[i].replace(p[1], source_type)
        if 'SOURCE_DEPTH' in lines3[i]:
            p = lines3[i].split()
            lines3[i] = lines3[i].replace(p[1], source_dep)
        if 'SOURCE_LAT' in lines3[i]:
            p = lines3[i].split()
            lines3[i] = lines3[i].replace(p[1], ev_lat)
        if 'SOURCE_LON' in lines3[i]:
            p = lines3[i].split()
            lines3[i] = lines3[i].replace(p[1], ev_lon)
        if 'SOURCE_AMPLITUDE' in lines3[i]:
            p = lines3[i].split()
            lines3[i] = lines3[i].replace(p[1], source_amp)

with open(f"{SOLVER}/inparam_source", 'w') as fout:
    for item in lines3:
        fout.write("%s\n" % item)

with open(f"{SOLVER}/inparam_advanced", 'r') as fin:
    file5 = fin.read()
    lines5 = file5.splitlines()
    for i in range(0,len(lines5)):
        if 'SOURCE_FUNCTION' in lines5[i]:
            p = lines5[i].split()
            lines5[i] = lines5[i].replace(p[1], source_function)
        if 'SNAPSHOT_DT' in lines5[i]:
            p = lines5[i].split()
            lines5[i] = lines5[i].replace(p[1], snapshot_dt)
        if 'SNAPSHOTS_FORMAT' in lines5[i]:
            p = lines5[i].split()
            lines5[i] = lines5[i].replace(p[1], snapshots_format)
        if 'F_MIN' in lines5[i]:
            p = lines5[i].split()
            lines5[i] = lines5[i].replace(p[1], f_min)
        if 'F_MAX' in lines5[i]:
            p = lines5[i].split()
            lines5[i] = lines5[i].replace(p[1], f_max)
        if 'F_REFERENCE' in lines5[i] and 'QPL' not in lines5[i]:
            p = lines5[i].split()
            lines5[i] = lines5[i].replace(p[1], f_ref)
            
with open(f"{SOLVER}/inparam_advanced", 'w') as fout:
    for item in lines5:
        fout.write("%s\n" % item)

# %% [markdown]
# The next two cells run the AxiSEM mesher by changing to the right directory, calling the submit.csh script, and then tidying up the output

# %%
# %%bash -s "$MESHER"
# echo "This bash script knows about $1"
# cd $1
# ./submit.csh
# echo "Mesher complete"
# Out:
# This bash script knows about /Users/katdapre/Documents/Synthetics/axisem-9f0be2f/MESHER
# make: Nothing to be done for `all'.
# Using external mesh file  github_ice_shell.bm
# [1] 18009
# xmesh submitted, output in "OUTPUT"
# After the run, move the mesh to a new directory <meshdir> via:
# ./movemesh <meshdir>
# This will be located in ../SOLVER/MESHES/<meshdir>
# Yeah that's done
#      Meshing started on 05/20/2022 at 15h 17min
#
#      CLOCKS module Clocks.F90,v 3.0 2014/10/19
#      Realtime clock resolution=   1.0000000474974513E-003 (        1000  ticks/sec)
# Reading inparam_mesh... done
#
#  PREDEFINED MODEL/SIMULATION PARAMETERS
#  Background model                 : external
#  Dominant period [s]              :   0.50000000000000000
#  Elements per dominant wavelength :    1.5000000000000000
#  Courant number                   :   0.60000002384185791
#  coarsening levels                :            0
#  processors used in solver        :            1
#  outer radius [m]                 :    252000.00000000000
#  save mesh info files?            :  F
#  print mesh info to screen?       :  F
#  path to dump output files        : Diags
#
#  MAIN: creating subregions/discontinuity model..........
#  Reading step-wise model from file: github_ice_shell.bm
#  Checking value order in external model
#   Value ' rad'  is in column  1
#   Value ' vpv'  is in column  3
#   Value ' vsv'  is in column  4
#   Value ' rho'  is in column  2
#  Model in file github_ice_shell.bm has    26 layers and is isotropic and elastic...
#  Depths/radii are assumed to be defined in meters
#  Layers in file github_ice_shell.bm start at surface
#  Checking for discontinuities in the external velocity model
#   2nd order disc. at radius    237419.0, layer:     6, gradient step vp:     0.00559, gradient step vs:     0.00276
#   1st order disc. at radius    198629.0, layer:    20
#   1st order disc. at radius    189080.0, layer:    22
#   1st order disc. at radius    160430.0, layer:    24
#  External model has   5 discontinuities
#
#  Creating interpolation objects
#     idom, upper_layer, lower_layer,      r(ul),      r(ll)
#        1            1            6    252000.0    237419.0
#        2            6           20    237419.0    198629.0
#        3           21           22    198629.0    189080.0
#        4           23           24    189080.0    160430.0
#        5           25           26    160430.0         0.0
#
#  Writing out the current model to Diags/1dmodel.bm
#  Domain:  1, width:      14581.0, step:  -2916
#  Domain:  2, width:      38790.0, step:  -7758
#  Domain:  3, width:       9549.0, step:  -1909
#  Domain:  4, width:      28650.0, step:  -5730
#  Domain:  5, width:     160430.0, step: -32086
#
#  #######################################################################
#   discontinuities:               1   252000.00
#   solid/fluid domain:            T           0
#   upper/lower radius:    252000.00   237419.00
#   vs jump:                 1964.35     1980.76
#  #######################################################################
#
#  #######################################################################
#   discontinuities:               2   237419.00
#   solid/fluid domain:            T           0
#   upper/lower radius:    237419.00   198629.00
#   vs jump:                 1980.76     1980.72
#  #######################################################################
#
#  #######################################################################
#   discontinuities:               3   198629.00
#   solid/fluid domain:            F           0
#   upper/lower radius:    198629.00   189080.00
#   vs jump:                    0.00        0.00
#  #######################################################################
#
#  #######################################################################
#   discontinuities:               4   189080.00
#   solid/fluid domain:            T           0
#   upper/lower radius:    189080.00   160430.00
#   vs jump:                 2480.00     2480.00
#  #######################################################################
#
#  #######################################################################
#   discontinuities:               5   160430.00
#   solid/fluid domain:            T           0
#   upper/lower radius:    160430.00        0.00
#   vs jump:                 4500.00     4500.00
#  #######################################################################
#
#           Number of discontinuities/regions:       5
#           Number of fluid regions:                 1
#
#  Constructing the mesh....
#
#
#           Spherical shell part of the mesh:
#           Total number of depth levels:           185
#           Actual number of coarsening levels:       0
#           Anticipated number of coarsening levels:  0
#  MAIN: generating skeleton..............................
#    8.8383836878670589E-004   1.2631051348055795E-003         792
#  estimate aspect ratio...
#  define spherical shell...
#  define central region...
#  gather skeleton...
#
#           SKELETON INFORMATIONS (NORTHERN HEMISPHERE ONLY)
#
#           Number of elements in the outer shell:        146520
#           Number of elements in the inner shell:             0
#           Number of elements in the buffer layer:          792
#           Number of elements in the central square:     156816
#
#           Total num. of elements in northern skel.:     304128
#
#
#  generate southern hemisphere...
#
#            THE TOTAL NUMBER OF ELEMENTS IS     608256
#
#  MAIN: creating gllmesh.................................
#  MAIN: glob-glob numbering..............................
#  MAIN: defining regions.................................
#
#  MAIN: test model.......................................
#  calculate GLL spacing...
#  starting big loop....
#  minmax vp:   1400.00000       7800.00000
#  ...saved Diags/mesh_vp.vtk
#  minmax vs:   0.00000000       4500.00000
#  ...saved Diags/mesh_vs.vtk
#  minmax rho:   917.610229       3400.00000
#  ...saved Diags/mesh_rho.vtk
#  computing vtk file Diags/mesh_eltype ...
#  ...saved Diags/mesh_eltype.vtk
#  computing vtk file Diags/mesh_hmax ...
#  ...saved Diags/mesh_hmax.vtk
#  minmax hmax:  0.247251675       1.10569882
#  computing vtk file Diags/mesh_hmax ...
#  ...saved Diags/mesh_hmax.vtk
#  minmax hmin:   1.00000000       9.50426674
#  computing vtk file Diags/mesh_hmin ...
#  ...saved Diags/mesh_hmin.vtk
#  minmax pts wavelngth:   5.42643261       24.2667732
#  computing vtk file Diags/mesh_pts_wavelength ...
#  ...saved Diags/mesh_pts_wavelength.vtk
#  minmax courant:   6.31295443E-02  0.600000024
#  computing vtk file Diags/mesh_courant ...
#  ...saved Diags/mesh_courant.vtk
#  minmax dt:   2.47836974E-03   2.35550869E-02
#  computing vtk file Diags/mesh_dt ...
#  ...saved Diags/mesh_dt.vtk
#  minmax period:  0.123625837      0.552849412
#  computing vtk file Diags/mesh_period ...
#  ...saved Diags/mesh_period.vtk
#  char max:  0.78757876984123809        40.606273703429785        9.2141568798811760E-002
#  char min:  0.75852757936509907        34.012864899741651        3.9258477362494659E-002
#  MAIN: define subregions................................
#  MAIN: glob-slob/flob numbering.........................
#  MAIN: boundaries.......................................
#  ..... the number of fluid boundaries is not general enough....
#  .....should insert a test on whether the fluid is indeed completely embedded!
#  size idom_fluid:           5           2
#  allocating boundary arrays....        3168
#  Done with boundary neighbor search.
#  MAIN: domain decomposition.............................
#       creating domain decomposition....
#       THETA-SLICING as domain decomposition....
#  computing vtk file Diags/mesh_domaindecomposition ...
#  ...saved Diags/mesh_domaindecomposition.vtk
#  ...saved Diags/mesh_domaindecomposition_cell.vtk
#  MAIN: creating parallel database.......................
#    define glocal numbering....
#    define solflu coordinates....
#    define axial elems....
#  NAXEL:        1164          60   1.2785240342310932E-005
#    define solflu numbering....
#    define search sflobal index....
#    partition sflobal index....
#  End of solid messaging
#
#    define local bdry elems....
#    generate processor serendipity....
#    define element type....
#    write database....
#  ....Wrote database for processor           0
#   create static header mesh_params.h ....
#  wrote parameters for static solver into mesh_params.h
#
#           Summary of timing measurements:
#
#                                            calls        t_call       t_total t_frac
# CLOCKS: mergesort                             10      2.035500     20.355001  0.613
# CLOCKS: mergesort - ind                       10      0.065700      0.657000  0.020
# CLOCKS: generate_skeleton                      1      1.785000      1.785000  0.054
# CLOCKS: create_gllmesh                         1      1.690000      1.690000  0.051
# CLOCKS: define_global_global_numbering         1      5.706000      5.706000  0.172
# CLOCKS: bkgrdmodel_testing                     1      3.138000      3.138000  0.095
# CLOCKS: glob-slob/flob numbering               1      5.844000      5.844000  0.176
# CLOCKS: get_global no loop                     3      3.691000     11.073001  0.334
# CLOCKS: get_global in loop                     3      2.406667      7.220000  0.218
# CLOCKS: create_pdb                             1     14.538001     14.538001  0.438
# CLOCKS: define_glocal_numbering                1      6.027000      6.027000  0.182
# CLOCKS: define_sflocal_numbering               1      6.062000      6.062000  0.183
# CLOCKS: generate_serendipity_per_proc          1      1.720000      1.720000  0.052
# CLOCKS: Total measured time:      33.184002
#
#  ....DONE WITH MESHER !
# rm: No match.
# rm: No match.
# rm: No match.

# %%
# %%bash -s "$MESHER" "$run_name"
# cd $1
# ./movemesh.csh $2
# Out:
# Moving mesh from . to ../SOLVER/MESHES/github_2Hz_test13
# MESHER finished smoothly...
# Moving mesh to /Users/katdapre/Documents/Synthetics/axisem-9f0be2f/SOLVER/MESHES/github_2Hz_test13
# external
# Copying external model file github_ice_shell.bm
# Contents in /Users/katdapre/Documents/Synthetics/axisem-9f0be2f/SOLVER/MESHES/github_2Hz_test13 :
# 1dmodel_axisem.bm
# 1dmodel_yspec.bm
# Code
# OUTPUT
# external_model.bm
# inparam_mesh
# mesh_courant.vtk
# mesh_domaindecomposition.vtk
# mesh_domaindecomposition_cell.vtk
# mesh_dt.vtk
# mesh_eltype.vtk
# mesh_hmax.vtk
# mesh_hmin.vtk
# mesh_params.h
# mesh_period.vtk
# mesh_pts_wavelength.vtk
# mesh_rho.vtk
# mesh_vp.vtk
# mesh_vs.vtk
# meshdb.dat0000
# radial_velocity.dat
# Total size: 453M	.
# DONE.

# %% [markdown]
# The next cell switches to the solver directory and runs the submit.csh script there

# %%
# %%bash -s "$SOLVER" "$run_name"
# cd $1
# touch main.f90
# make all
# cd $1
# ./submit.csh $2
# Out:
# gfortran -O3 -march=native  -Dserial -Dsolver -c  main.f90
# gfortran -O3  -pthread -o axisem background_models.o commpi.o commun.o get_model.o lateral_heterogeneities.o meshes_io.o nc_helpers.o nc_routines.o nc_snapshots.o parameters.o time_evol_wave.o analytic_mapping.o analytic_semi_mapping.o analytic_spheroid_mapping.o apply_masks.o attenuation.o clocks.o clocks_wrapper_solver.o data_comm.o data_heterogeneous.o data_io.o data_matr.o data_mesh.o data_pointwise.o data_proc.o data_source.o data_spec.o data_time.o def_grid.o def_precomp_terms.o get_mesh.o global_parameters.o interpolation.o kdtree2.o list.o main.o pointwise_derivatives.o rotations.o seismograms.o source.o stiffness_di.o stiffness_fluid.o stiffness_mono.o stiffness_quad.o subpar_mapping.o unrolled_loops.o utlity.o wavefields_io.o ftz.o pthread.o
# Using mesh  MESHES/github_2Hz_test13
# copying mesh_params.h from  MESHES/github_2Hz_test13
# make: Nothing to be done for `all'.
# Receiver file type: colatlon
# Source file: inparam_source, Receiver file: receivers.dat
# source names: ./
# source components: mrr
# Create the run directory  github_2Hz_test13
# copying make_axisem.macros from ../
#
# Setting up simulation ./
# creating ./Info
# copying crucial files for the simulation...
# preparing job on 1 nodes...
# [1] 18276
# Job running in directory ./
# To convolve and sum seismograms, run ./post_processing.csh after the simulations in:
# /Users/katdapre/Documents/Synthetics/axisem-9f0be2f/SOLVER/github_2Hz_test13
# .... the post-processing input file param_post_processing is generated in the solver
# .... based on guesses. Edit please.
#  ~ ~ ~ ~ ~ ~ ~ h a n g   o n   &   l o o s e ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~
#     Initialized run for nproc =    1
#
#  MAIN: Welcome to AxiSEM!
#
#      Simulation started on 05/20/2022 at 15h 18min
#
#  MAIN: Reading parameters..................................
#
#         ///////////////////////////////////////////////////////////////
#         //                                                           //
#         //                  A   x   i   S   E   M                    //
#         //                                                           //
#         //                                                           //
#         //         Parallel spectral-element solution to             //
#         //                                                           //
#         //           3-D seismic wave propagation for                //
#         //                                                           //
#         //          axially symmetric background models              //
#         //                                                           //
#         //               in a spherical 2-D domain                   //
#         //                                                           //
#         //                                                           //
#         //  Authors : Tarje Nissen-Meyer (Oxford University)         //
#         //              Martin van Driel (ETH Zurich)                //
#         //                 Simon Stähler (LMU Munich)                //
#         //                Kasra Hosseini (LMU Munich)                //
#         //               Stefanie Hempel (University of Muenster)    //
#         //            Alexandre Fournier (IPG Paris)                 //
#         //                   Tony Dahlen (Princeton University)      //
#         //                                                           //
#         //   Contact:     info@axisem.info                           //
#         //   Information: www.axisem.info                            //
#         //                                                           //
#
#         //                                                           //
#         //     If you are publishing results obtained with this      //
#         //          code, please cite this paper:                    //
#         //                                                           //
#         // (1) T. Nissen-Meyer, M. van Driel, S. C. Staehler,        //
#         //     K. Hosseini, S. Hempel, L. Auer, A. Colombi           //
#         //     and A. Fournier:                                      //
#         //     "AxiSEM: broadband 3-D seismic wavefields in          //
#         //              axisymmetric media"                          //
#         //     Solid Earth, 5, 425-445, 2014                         //
#         //     doi:10.5194/se-5-425-2014                             //
#         //                                                           //
#         //       Comprehensive description of the underlying         //
#         //           numerical analysis can be found in:             //
#         //                                                           //
#         // (2) Tarje Nissen-Meyer, F. A. Dahlen, A Fournier (2007)   //
#         //     "Spherical-earth Frechet sensitivity kernels"         //
#         //     Geophysical Journal International 168(3),1051-1066.   //
#         //     doi:10.1111/j.1365-246X.2006.03123.x                  //
#         //                                                           //
#         // (3) Tarje Nissen-Meyer, A Fournier, F. A. Dahlen (2007)   //
#         //     "A two-dimensional spectral-element method for        //
#         //        computing spherical-earth seismograms -            //
#         //        I. Moment-tensor source"                           //
#         //     Geophysical Journal International 168(3), 1067-1092.  //
#         //     doi:10.1111/j.1365-246X.2006.03121.x                  //
#         //                                                           //
#         // (4) Tarje Nissen-Meyer, A Fournier, F. A. Dahlen (2007)   //
#         //     "A two-dimensional spectral-element method for        //
#         //        computing spherical-earth seismograms -            //
#         //        II.  Waves in solid-fluid media"                   //
#         //     Geophysical Journal International 174(3), 873-888.    //
#         //     doi:10.1111/j.1365-246X.2008.03813.x                  //
#         //                                                           //
#         // (5) Martin van Driel and Tarje Nissen-Meyer (2014)        //
#         //     "Seismic wave propagation in fully anisotropic        //
#         //        axisymmetric media"                                //
#         //      Geophysical Journal International 199 (2): 880-893.  //
#         //      doi: 10.1093/gji/ggu269                              //
#         //                                                           //
#         // (6) Martin van Driel and Tarje Nissen-Meyer (2014)        //
#         //     "Optimized visco-elastic wave propagation for         //
#         //        weakly dissipative media"                          //
#         //      Geophysical Journal International 199 (2): 1078-1093.//
#         //      doi: 10.1093/gji/ggu314                              //
#         //                                                           //
#         //                                                           //
#         //  April 2016: version 1.3                                  //
#         //                                                           //
#         ///////////////////////////////////////////////////////////////
#
#         =============  I N P U T    P A R A M E T E R S ===============
#             Data I/O path:                      ./Data
#             Info I/O path:                      ./Info
#             Simulation length [s]:                200.000
#             Enforced time step [s]:               0.000
#             Enforced source period [s]:           0.000
#             Simulation type:                    single
#             Receiver file type:                 colatlon
#             Sum seismograms?                     F
#             Sum wavefields?                      F
#             Time extrapolation scheme:          newmark2
#             Seismogram sampling rate [s]:         0.000
#             Dump kin./pot. energy?               F
#             Dump global snaps?                   F
#             Dump strain?                         F
#             Wavefield dumping type:             displ_only
#             First GLL to save in strains:        1
#             Last GLL to save in strains:         3
#             First GLL to save in strains:        1
#             Last GLL to save in strains:         3
#             Samples per period for strains:       4.000
#             Source dumping type:                igno
#             Add heterogeneous region?            F
#             Perform extensive mesh tests?        F
#             Output format (seism., wavefields): binary
#         ===============================================================
#  MAIN: Reading mesh database...............................
#
#    General numerical input/output parameters================
#      grid pts/wavelngth =   1.5000000000000000
#      source period [s]  =  0.50000000000000000
#      courant number     =  0.60000002384185791
#      time step [s]      =   2.4783697648372198E-003
#  Checking value order in external model
#   Value ' rad'  is in column  1
#   Value ' vpv'  is in column  3
#   Value ' vsv'  is in column  4
#   Value ' rho'  is in column  2
#  Model in file ./external_model.bm has    26 layers and is isotropic and elastic...
#  Depths/radii are assumed to be defined in meters
#  Layers in file ./external_model.bm start at surface
#  Checking for discontinuities in the external velocity model
#   2nd order disc. at radius    237419.0, layer:     6, gradient step vp:     0.00559, gradient step vs:     0.00276
#   1st order disc. at radius    198629.0, layer:    20
#   1st order disc. at radius    189080.0, layer:    22
#   1st order disc. at radius    160430.0, layer:    24
#  External model has   5 discontinuities
#
#  Creating interpolation objects
#     idom, upper_layer, lower_layer,      r(ul),      r(ll)
#        1            1            6    252000.0    237419.0
#        2            6           20    237419.0    198629.0
#        3           21           22    198629.0    189080.0
#        4           23           24    189080.0    160430.0
#        5           25           26    160430.0         0.0
#
#
#    Background model=========================================
#      bkgrdmodel = external
#      radius [m] =    252000.00000000000
#      have_fluid =  T
#
#    Min/max grid spacing=====================================
#      hmin (global) [m]   :    32.218805662623545
#      hmax (global) [m]   :    376.29738267744000
#      min_distance_dim [m]:    3.2218805662623549
#
#    Axialogy=================================================
#
#      Global total axial elements:        1164
#      Global solid axial elements:        1104
#      Global fluid axial elements:          60
#
#
#  MAIN: Initializing grid...................................
#  MAIN: Starting wave preparation...........................
#
#  ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#  ++++++++    SEISMIC WAVE PROPAGATION: SOLID-FLUID CASE  ++++++++
#  ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#    *****************GIVEN SOURCE PARAMETERS*****************
#       Magnitude [Nm]:             1.000E+13
#       Excitation type:        monopole    mrr
#       Depth [km]:                 5.000E+00
#       Colat. [deg]:               0.000E+00
#       Long. [deg]:                0.000E+00
#       Source time function:       gauss_0
#       Dom. period mesh [s]:          0.5000
#    *********************************************************
#
#
#      Using period of the mesh:  0.50000000000000000
#
#      desired simulation length  :   200.00   seconds
#      offered simulation length  :   200.00   seconds
#      number time loop iterations:   80699
#
#      desired seismogram sampling:     0.00   seconds
#      offered seismogram sampling:     0.00   seconds
#      ...that is, every          :       1 timesteps
#      number of samples          :   80700
#
#    *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#    SOURCE TIME FUNCTION: gauss_0
#     coarsest dump every           1 th time step, dt:   2.4783697648372198E-003
#
#    SHIFT FACTOR of source time function [s]:  0.750946045
#     # SEM, seis, coarse points per shift factor:   303.000000       303.000000       303.000000
#     # simul. half widths per shift factor:   1.50189209
#    *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
#
#   ::::::::: BACKGROUND MODEL & PRECOMPUTED MATRICES:::::::
#   :::::::DONE BACKGROUND MODEL & PRECOMPUTED MATRICES:::::
#   *****************************************
#      Welcome to the source term calculator
#   *****************************************
#   locating the source....
#    Proc 00  found it:
#      depth asked for [km]:   5.0000000000000000
#      depth offered   [km]:   4.9442582471228089
#      difference      [km]:   5.5741752877191172E-002
#    computing MONOPOLE Source with...
#    ...moment tensor elements for mrr
#    Proc 00 computing source field z-component for Mzz
#    ...masked the source
#   number of elements with non-zero source term: 3
#   *********************************
#      End of source term calculator
#   *********************************
#    locating surface elements and generic receivers...
#    ensuring uniqueness in generic receiver locations...
#    Proc 00 has the  epicenter at    0.000 degrees.
#    Proc 00 has the    equator at   90.000 degrees.
#    Proc 00 has the   antipode at  180.000 degrees.
#    reading receiver colatitudes and longitudes from receivers.dat...
#    # total receivers:          25
#
#    maximal receiver location error [m]:   51.283867417829022
#
#    Calculating prefactors for cylindrical components...
#
#    checking input parameters for consistency...
#
#  :::::::::::::::: SIMULATION PARAMETERS::::::::::::::::::::::::
#    Code information_____________________________________
#       svn revision      :   67c9-dirty
#       username          :   katdapre
#       hostname          :   IT047636
#       compiler          :   gfortran
#       compilerversion   :   9.3.0
#       FFLAGS            :   FFLAGS = -O3 -march=native #-fopenmp
#       CFLAGS            :   CFLAGS = -Wno-error=implicit-function-declaration -
#       LDFLAGS           :   LDFLAGS = -O3 #-march=native #-fopenmp
#       OpenMP            :                  no
#    Global mesh information______________________________
#       Background model  :   external
#       # discontinuities :             5
#       Have fluid region ?             T
#       Outer rad.     [m]:   2.52000E+05
#       Inner rad.     [m]:   1.59399E+05
#       Polynomial order  :             4
#       # control nodes   :       1827517
#       Total elements    :        608256
#       Total # points    :      15206400
#       # global numbers  :       9737593
#       # axial elements  :          1164
#       # curved elements :        293040
#       # linear elements :        313632
#       # mixed elements  :          1584
#       Min. distance  [m]:   3.22188E+00
#       Min. distance/r0  :   1.27852E-05
#    Grid spacing, velocities etc.________________________
#       Min. (pre,comp)[m]:    3.222E+01    3.222E+01
#       Max. (pre,comp)[m]:    3.763E+02    3.763E+02
#       Min. vp[m/s], r[m]:    1.400E+03    1.983E+05
#       Min. vs[m/s], r[m]:    0.000E+00    1.983E+05
#       Max. vp[m/s], r[m]:    7.800E+03    0.000E+00
#       Max. vs[m/s], r[m]:    4.500E+03    0.000E+00
#       Max. lead time [s]:   9.21416E-02
#       r [m], theta [deg]:    1.985E+05    4.061E+01
#       Min. lead time [s]:   3.92585E-02
#       r [m], theta [deg]:    1.911E+05    3.401E+01
#    Solid-Fluid configuration____________________________
#       S/F elements      :        560736    47520
#       S/F # points      :      14018400  1188000
#       S/F global numbers:       8983490   766777
#       S/F # axial elems :          1104       60
#       # S/F boundary els:          3168
#       S/F curved elems  :        245520    47520
#       S/F linear elems  :        313632        0
#       S/F mixed elements:          1584        0
#    Solid message passing_________________________________
#       # processors      :             1
#       max. sent messages:             0
#       max. sent size    :             0
#       nax. recv messages:             0
#       max. recv size    :             0
#    Fluid message passing_________________________________
#       max. sent messages:             0
#       max. sent size    :             0
#       nax. recv messages:             0
#       max. recv size    :             0
#    Source information___________________________________
#       Source type       :   monopole  mrr
#       Source depth   [m]:   2.47056E+05
#       Source colat [deg]:   0.00000E+00
#       Source long  [deg]:   0.00000E+00
#       Magnitude    [N/m]:   1.00000E+13
#       Source time fct   :              gauss_0
#       Dom. period    [s]:   5.00000E-01
#    Receiver information___________________________________
#        Receiver file type             colatlon
#        Sum seismograms  :             F
#    General numerical parameters_________________________
#       # elems/wavelength:   1.50000E+00
#       Courant number    :   6.00000E-01
#       Time step [s]     :   2.47837E-03
#       # iterations      :         80699
#       seismo length [s] :   2.00002E+02
#       time extrapolation:             newmark2
#    Input/Output information_____________________________
#       Output data path  :               ./Data
#       Output info path  :               ./Info
#           Sum wavefields:             F
#       Dump energy       :             F
#       XDMF VTK          :             F
#       Dump wavefields   :             F
#       Need fluid displ. :             F
#
#  :::::::::::::::: END SIMULATION PARAMETERS::::::::::::::::::::
#
#
#    wrote general simulation info into "simulation.info"
#    Writing post processing input file: param_post_processing
#    ... mainly based on guessing from the current simulation, make sure to edit!
#      ... wrote file param_post_processing
#  done preparing waves.
#  MAIN: Deallocating arrays not needed in the time loop.....
#    deallocating large mesh arrays...
#    deallocating pointwise fluid arrays...
#    deallocating pointwise solid arrays...
#    Done deallocating mesh arrays.
#  MAIN: Starting wave propagation...........................
#
#  TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
#  TTTT  2nd-order, acceleration-driven Newmark time scheme TTTTT
#  TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
#
#  ************ S T A R T I N G   T I M E   L O O P *************
#   time step:   100; t=    0.25 s (  0.1%)
#   time step:   200; t=    0.50 s (  0.2%)
#   time step:   300; t=    0.74 s (  0.4%)
#   time step:   400; t=    0.99 s (  0.5%)
#   time step:   500; t=    1.24 s (  0.6%)
#   time step:   600; t=    1.49 s (  0.7%)
#   time step:   700; t=    1.73 s (  0.9%)
#   time step:   800; t=    1.98 s (  1.0%)
#   time step:   900; t=    2.23 s (  1.1%)
#   time step:  1000; t=    2.48 s (  1.2%)
#   time step:  1100; t=    2.73 s (  1.4%)
#   time step:  1200; t=    2.97 s (  1.5%)
#   time step:  1300; t=    3.22 s (  1.6%)
#   time step:  1400; t=    3.47 s (  1.7%)
#   time step:  1500; t=    3.72 s (  1.9%)
#   time step:  1600; t=    3.97 s (  2.0%)
#   time step:  1700; t=    4.21 s (  2.1%)
#   time step:  1800; t=    4.46 s (  2.2%)
#   time step:  1900; t=    4.71 s (  2.4%)
#   time step:  2000; t=    4.96 s (  2.5%)
#   time step:  2100; t=    5.20 s (  2.6%)
#   time step:  2200; t=    5.45 s (  2.7%)
#   time step:  2300; t=    5.70 s (  2.9%)
#   time step:  2400; t=    5.95 s (  3.0%)
#   time step:  2500; t=    6.20 s (  3.1%)
#   time step:  2600; t=    6.44 s (  3.2%)
#   time step:  2700; t=    6.69 s (  3.3%)
#   time step:  2800; t=    6.94 s (  3.5%)
#   time step:  2900; t=    7.19 s (  3.6%)
#   time step:  3000; t=    7.44 s (  3.7%)
#   time step:  3100; t=    7.68 s (  3.8%)
#   time step:  3200; t=    7.93 s (  4.0%)
#   time step:  3300; t=    8.18 s (  4.1%)
#   time step:  3400; t=    8.43 s (  4.2%)
#   time step:  3500; t=    8.67 s (  4.3%)
#   time step:  3600; t=    8.92 s (  4.5%)
#   time step:  3700; t=    9.17 s (  4.6%)
#   time step:  3800; t=    9.42 s (  4.7%)
#   time step:  3900; t=    9.67 s (  4.8%)
#   time step:  4000; t=    9.91 s (  5.0%)
#   time step:  4100; t=   10.16 s (  5.1%)
#   time step:  4200; t=   10.41 s (  5.2%)
#   time step:  4300; t=   10.66 s (  5.3%)
#   time step:  4400; t=   10.90 s (  5.5%)
#   time step:  4500; t=   11.15 s (  5.6%)
#   time step:  4600; t=   11.40 s (  5.7%)
#   time step:  4700; t=   11.65 s (  5.8%)
#   time step:  4800; t=   11.90 s (  5.9%)
#   time step:  4900; t=   12.14 s (  6.1%)
#   time step:  5000; t=   12.39 s (  6.2%)
#   time step:  5100; t=   12.64 s (  6.3%)
#   time step:  5200; t=   12.89 s (  6.4%)
#   time step:  5300; t=   13.14 s (  6.6%)
#   time step:  5400; t=   13.38 s (  6.7%)
#   time step:  5500; t=   13.63 s (  6.8%)
#   time step:  5600; t=   13.88 s (  6.9%)
#   time step:  5700; t=   14.13 s (  7.1%)
#   time step:  5800; t=   14.37 s (  7.2%)
#   time step:  5900; t=   14.62 s (  7.3%)
#   time step:  6000; t=   14.87 s (  7.4%)
#   time step:  6100; t=   15.12 s (  7.6%)
#   time step:  6200; t=   15.37 s (  7.7%)
#   time step:  6300; t=   15.61 s (  7.8%)
#   time step:  6400; t=   15.86 s (  7.9%)
#   time step:  6500; t=   16.11 s (  8.1%)
#   time step:  6600; t=   16.36 s (  8.2%)
#   time step:  6700; t=   16.61 s (  8.3%)
#   time step:  6800; t=   16.85 s (  8.4%)
#   time step:  6900; t=   17.10 s (  8.6%)
#   time step:  7000; t=   17.35 s (  8.7%)
#   time step:  7100; t=   17.60 s (  8.8%)
#   time step:  7200; t=   17.84 s (  8.9%)
#   time step:  7300; t=   18.09 s (  9.0%)
#   time step:  7400; t=   18.34 s (  9.2%)
#   time step:  7500; t=   18.59 s (  9.3%)
#   time step:  7600; t=   18.84 s (  9.4%)
#   time step:  7700; t=   19.08 s (  9.5%)
#   time step:  7800; t=   19.33 s (  9.7%)
#   time step:  7900; t=   19.58 s (  9.8%)
#   time step:  8000; t=   19.83 s (  9.9%)
#   time step:  8100; t=   20.07 s ( 10.0%)
#   time step:  8200; t=   20.32 s ( 10.2%)
#   time step:  8300; t=   20.57 s ( 10.3%)
#   time step:  8400; t=   20.82 s ( 10.4%)
#   time step:  8500; t=   21.07 s ( 10.5%)
#   time step:  8600; t=   21.31 s ( 10.7%)
#   time step:  8700; t=   21.56 s ( 10.8%)
#   time step:  8800; t=   21.81 s ( 10.9%)
#   time step:  8900; t=   22.06 s ( 11.0%)
#   time step:  9000; t=   22.31 s ( 11.2%)
#   time step:  9100; t=   22.55 s ( 11.3%)
#   time step:  9200; t=   22.80 s ( 11.4%)
#   time step:  9300; t=   23.05 s ( 11.5%)
#   time step:  9400; t=   23.30 s ( 11.6%)
#   time step:  9500; t=   23.54 s ( 11.8%)
#   time step:  9600; t=   23.79 s ( 11.9%)
#   time step:  9700; t=   24.04 s ( 12.0%)
#   time step:  9800; t=   24.29 s ( 12.1%)
#   time step:  9900; t=   24.54 s ( 12.3%)
#   time step: 10000; t=   24.78 s ( 12.4%)
#   time step: 10100; t=   25.03 s ( 12.5%)
#   time step: 10200; t=   25.28 s ( 12.6%)
#   time step: 10300; t=   25.53 s ( 12.8%)
#   time step: 10400; t=   25.78 s ( 12.9%)
#   time step: 10500; t=   26.02 s ( 13.0%)
#   time step: 10600; t=   26.27 s ( 13.1%)
#   time step: 10700; t=   26.52 s ( 13.3%)
#   time step: 10800; t=   26.77 s ( 13.4%)
#   time step: 10900; t=   27.01 s ( 13.5%)
#   time step: 11000; t=   27.26 s ( 13.6%)
#   time step: 11100; t=   27.51 s ( 13.8%)
#   time step: 11200; t=   27.76 s ( 13.9%)
#   time step: 11300; t=   28.01 s ( 14.0%)
#   time step: 11400; t=   28.25 s ( 14.1%)
#   time step: 11500; t=   28.50 s ( 14.3%)
#   time step: 11600; t=   28.75 s ( 14.4%)
#   time step: 11700; t=   29.00 s ( 14.5%)
#   time step: 11800; t=   29.24 s ( 14.6%)
#   time step: 11900; t=   29.49 s ( 14.7%)
#   time step: 12000; t=   29.74 s ( 14.9%)
#   time step: 12100; t=   29.99 s ( 15.0%)
#   time step: 12200; t=   30.24 s ( 15.1%)
#   time step: 12300; t=   30.48 s ( 15.2%)
#   time step: 12400; t=   30.73 s ( 15.4%)
#   time step: 12500; t=   30.98 s ( 15.5%)
#   time step: 12600; t=   31.23 s ( 15.6%)
#   time step: 12700; t=   31.48 s ( 15.7%)
#   time step: 12800; t=   31.72 s ( 15.9%)
#   time step: 12900; t=   31.97 s ( 16.0%)
#   time step: 13000; t=   32.22 s ( 16.1%)
#   time step: 13100; t=   32.47 s ( 16.2%)
#   time step: 13200; t=   32.71 s ( 16.4%)
#   time step: 13300; t=   32.96 s ( 16.5%)
#   time step: 13400; t=   33.21 s ( 16.6%)
#   time step: 13500; t=   33.46 s ( 16.7%)
#   time step: 13600; t=   33.71 s ( 16.9%)
#   time step: 13700; t=   33.95 s ( 17.0%)
#   time step: 13800; t=   34.20 s ( 17.1%)
#   time step: 13900; t=   34.45 s ( 17.2%)
#   time step: 14000; t=   34.70 s ( 17.3%)
#   time step: 14100; t=   34.95 s ( 17.5%)
#   time step: 14200; t=   35.19 s ( 17.6%)
#   time step: 14300; t=   35.44 s ( 17.7%)
#   time step: 14400; t=   35.69 s ( 17.8%)
#   time step: 14500; t=   35.94 s ( 18.0%)
#   time step: 14600; t=   36.18 s ( 18.1%)
#   time step: 14700; t=   36.43 s ( 18.2%)
#   time step: 14800; t=   36.68 s ( 18.3%)
#   time step: 14900; t=   36.93 s ( 18.5%)
#   time step: 15000; t=   37.18 s ( 18.6%)
#   time step: 15100; t=   37.42 s ( 18.7%)
#   time step: 15200; t=   37.67 s ( 18.8%)
#   time step: 15300; t=   37.92 s ( 19.0%)
#   time step: 15400; t=   38.17 s ( 19.1%)
#   time step: 15500; t=   38.41 s ( 19.2%)
#   time step: 15600; t=   38.66 s ( 19.3%)
#   time step: 15700; t=   38.91 s ( 19.5%)
#   time step: 15800; t=   39.16 s ( 19.6%)
#   time step: 15900; t=   39.41 s ( 19.7%)
#   time step: 16000; t=   39.65 s ( 19.8%)
#   time step: 16100; t=   39.90 s ( 20.0%)
#   time step: 16200; t=   40.15 s ( 20.1%)
#   time step: 16300; t=   40.40 s ( 20.2%)
#   time step: 16400; t=   40.65 s ( 20.3%)
#   time step: 16500; t=   40.89 s ( 20.4%)
#   time step: 16600; t=   41.14 s ( 20.6%)
#   time step: 16700; t=   41.39 s ( 20.7%)
#   time step: 16800; t=   41.64 s ( 20.8%)
#   time step: 16900; t=   41.88 s ( 20.9%)
#   time step: 17000; t=   42.13 s ( 21.1%)
#   time step: 17100; t=   42.38 s ( 21.2%)
#   time step: 17200; t=   42.63 s ( 21.3%)
#   time step: 17300; t=   42.88 s ( 21.4%)
#   time step: 17400; t=   43.12 s ( 21.6%)
#   time step: 17500; t=   43.37 s ( 21.7%)
#   time step: 17600; t=   43.62 s ( 21.8%)
#   time step: 17700; t=   43.87 s ( 21.9%)
#   time step: 17800; t=   44.11 s ( 22.1%)
#   time step: 17900; t=   44.36 s ( 22.2%)
#   time step: 18000; t=   44.61 s ( 22.3%)
#   time step: 18100; t=   44.86 s ( 22.4%)
#   time step: 18200; t=   45.11 s ( 22.6%)
#   time step: 18300; t=   45.35 s ( 22.7%)
#   time step: 18400; t=   45.60 s ( 22.8%)
#   time step: 18500; t=   45.85 s ( 22.9%)
#   time step: 18600; t=   46.10 s ( 23.0%)
#   time step: 18700; t=   46.35 s ( 23.2%)
#   time step: 18800; t=   46.59 s ( 23.3%)
#   time step: 18900; t=   46.84 s ( 23.4%)
#   time step: 19000; t=   47.09 s ( 23.5%)
#   time step: 19100; t=   47.34 s ( 23.7%)
#   time step: 19200; t=   47.58 s ( 23.8%)
#   time step: 19300; t=   47.83 s ( 23.9%)
#   time step: 19400; t=   48.08 s ( 24.0%)
#   time step: 19500; t=   48.33 s ( 24.2%)
#   time step: 19600; t=   48.58 s ( 24.3%)
#   time step: 19700; t=   48.82 s ( 24.4%)
#   time step: 19800; t=   49.07 s ( 24.5%)
#   time step: 19900; t=   49.32 s ( 24.7%)
#   time step: 20000; t=   49.57 s ( 24.8%)
#   time step: 20100; t=   49.82 s ( 24.9%)
#   time step: 20200; t=   50.06 s ( 25.0%)
#   time step: 20300; t=   50.31 s ( 25.2%)
#   time step: 20400; t=   50.56 s ( 25.3%)
#   time step: 20500; t=   50.81 s ( 25.4%)
#   time step: 20600; t=   51.05 s ( 25.5%)
#   time step: 20700; t=   51.30 s ( 25.7%)
#   time step: 20800; t=   51.55 s ( 25.8%)
#   time step: 20900; t=   51.80 s ( 25.9%)
#   time step: 21000; t=   52.05 s ( 26.0%)
#   time step: 21100; t=   52.29 s ( 26.1%)
#   time step: 21200; t=   52.54 s ( 26.3%)
#   time step: 21300; t=   52.79 s ( 26.4%)
#   time step: 21400; t=   53.04 s ( 26.5%)
#   time step: 21500; t=   53.28 s ( 26.6%)
#   time step: 21600; t=   53.53 s ( 26.8%)
#   time step: 21700; t=   53.78 s ( 26.9%)
#   time step: 21800; t=   54.03 s ( 27.0%)
#   time step: 21900; t=   54.28 s ( 27.1%)
#   time step: 22000; t=   54.52 s ( 27.3%)
#   time step: 22100; t=   54.77 s ( 27.4%)
#   time step: 22200; t=   55.02 s ( 27.5%)
#   time step: 22300; t=   55.27 s ( 27.6%)
#   time step: 22400; t=   55.52 s ( 27.8%)
#   time step: 22500; t=   55.76 s ( 27.9%)
#   time step: 22600; t=   56.01 s ( 28.0%)
#   time step: 22700; t=   56.26 s ( 28.1%)
#   time step: 22800; t=   56.51 s ( 28.3%)
#   time step: 22900; t=   56.75 s ( 28.4%)
#   time step: 23000; t=   57.00 s ( 28.5%)
#   time step: 23100; t=   57.25 s ( 28.6%)
#   time step: 23200; t=   57.50 s ( 28.7%)
#   time step: 23300; t=   57.75 s ( 28.9%)
#   time step: 23400; t=   57.99 s ( 29.0%)
#   time step: 23500; t=   58.24 s ( 29.1%)
#   time step: 23600; t=   58.49 s ( 29.2%)
#   time step: 23700; t=   58.74 s ( 29.4%)
#   time step: 23800; t=   58.99 s ( 29.5%)
#   time step: 23900; t=   59.23 s ( 29.6%)
#   time step: 24000; t=   59.48 s ( 29.7%)
#   time step: 24100; t=   59.73 s ( 29.9%)
#   time step: 24200; t=   59.98 s ( 30.0%)
#   time step: 24300; t=   60.22 s ( 30.1%)
#   time step: 24400; t=   60.47 s ( 30.2%)
#   time step: 24500; t=   60.72 s ( 30.4%)
#   time step: 24600; t=   60.97 s ( 30.5%)
#   time step: 24700; t=   61.22 s ( 30.6%)
#   time step: 24800; t=   61.46 s ( 30.7%)
#   time step: 24900; t=   61.71 s ( 30.9%)
#   time step: 25000; t=   61.96 s ( 31.0%)
#   time step: 25100; t=   62.21 s ( 31.1%)
#   time step: 25200; t=   62.45 s ( 31.2%)
#   time step: 25300; t=   62.70 s ( 31.4%)
#   time step: 25400; t=   62.95 s ( 31.5%)
#   time step: 25500; t=   63.20 s ( 31.6%)
#   time step: 25600; t=   63.45 s ( 31.7%)
#   time step: 25700; t=   63.69 s ( 31.8%)
#   time step: 25800; t=   63.94 s ( 32.0%)
#   time step: 25900; t=   64.19 s ( 32.1%)
#   time step: 26000; t=   64.44 s ( 32.2%)
#   time step: 26100; t=   64.69 s ( 32.3%)
#   time step: 26200; t=   64.93 s ( 32.5%)
#   time step: 26300; t=   65.18 s ( 32.6%)
#   time step: 26400; t=   65.43 s ( 32.7%)
#   time step: 26500; t=   65.68 s ( 32.8%)
#   time step: 26600; t=   65.92 s ( 33.0%)
#   time step: 26700; t=   66.17 s ( 33.1%)
#   time step: 26800; t=   66.42 s ( 33.2%)
#   time step: 26900; t=   66.67 s ( 33.3%)
#   time step: 27000; t=   66.92 s ( 33.5%)
#   time step: 27100; t=   67.16 s ( 33.6%)
#   time step: 27200; t=   67.41 s ( 33.7%)
#   time step: 27300; t=   67.66 s ( 33.8%)
#   time step: 27400; t=   67.91 s ( 34.0%)
#   time step: 27500; t=   68.16 s ( 34.1%)
#   time step: 27600; t=   68.40 s ( 34.2%)
#   time step: 27700; t=   68.65 s ( 34.3%)
#   time step: 27800; t=   68.90 s ( 34.4%)
#   time step: 27900; t=   69.15 s ( 34.6%)
#   time step: 28000; t=   69.39 s ( 34.7%)
#   time step: 28100; t=   69.64 s ( 34.8%)
#   time step: 28200; t=   69.89 s ( 34.9%)
#   time step: 28300; t=   70.14 s ( 35.1%)
#   time step: 28400; t=   70.39 s ( 35.2%)
#   time step: 28500; t=   70.63 s ( 35.3%)
#   time step: 28600; t=   70.88 s ( 35.4%)
#   time step: 28700; t=   71.13 s ( 35.6%)
#   time step: 28800; t=   71.38 s ( 35.7%)
#   time step: 28900; t=   71.62 s ( 35.8%)
#   time step: 29000; t=   71.87 s ( 35.9%)
#   time step: 29100; t=   72.12 s ( 36.1%)
#   time step: 29200; t=   72.37 s ( 36.2%)
#   time step: 29300; t=   72.62 s ( 36.3%)
#   time step: 29400; t=   72.86 s ( 36.4%)
#   time step: 29500; t=   73.11 s ( 36.6%)
#   time step: 29600; t=   73.36 s ( 36.7%)
#   time step: 29700; t=   73.61 s ( 36.8%)
#   time step: 29800; t=   73.86 s ( 36.9%)
#   time step: 29900; t=   74.10 s ( 37.1%)
#   time step: 30000; t=   74.35 s ( 37.2%)
#   time step: 30100; t=   74.60 s ( 37.3%)
#   time step: 30200; t=   74.85 s ( 37.4%)
#   time step: 30300; t=   75.09 s ( 37.5%)
#   time step: 30400; t=   75.34 s ( 37.7%)
#   time step: 30500; t=   75.59 s ( 37.8%)
#   time step: 30600; t=   75.84 s ( 37.9%)
#   time step: 30700; t=   76.09 s ( 38.0%)
#   time step: 30800; t=   76.33 s ( 38.2%)
#   time step: 30900; t=   76.58 s ( 38.3%)
#   time step: 31000; t=   76.83 s ( 38.4%)
#   time step: 31100; t=   77.08 s ( 38.5%)
#   time step: 31200; t=   77.33 s ( 38.7%)
#   time step: 31300; t=   77.57 s ( 38.8%)
#   time step: 31400; t=   77.82 s ( 38.9%)
#   time step: 31500; t=   78.07 s ( 39.0%)
#   time step: 31600; t=   78.32 s ( 39.2%)
#   time step: 31700; t=   78.56 s ( 39.3%)
#   time step: 31800; t=   78.81 s ( 39.4%)
#   time step: 31900; t=   79.06 s ( 39.5%)
#   time step: 32000; t=   79.31 s ( 39.7%)
#   time step: 32100; t=   79.56 s ( 39.8%)
#   time step: 32200; t=   79.80 s ( 39.9%)
#   time step: 32300; t=   80.05 s ( 40.0%)
#   time step: 32400; t=   80.30 s ( 40.1%)
#   time step: 32500; t=   80.55 s ( 40.3%)
#   time step: 32600; t=   80.79 s ( 40.4%)
#   time step: 32700; t=   81.04 s ( 40.5%)
#   time step: 32800; t=   81.29 s ( 40.6%)
#   time step: 32900; t=   81.54 s ( 40.8%)
#   time step: 33000; t=   81.79 s ( 40.9%)
#   time step: 33100; t=   82.03 s ( 41.0%)
#   time step: 33200; t=   82.28 s ( 41.1%)
#   time step: 33300; t=   82.53 s ( 41.3%)
#   time step: 33400; t=   82.78 s ( 41.4%)
#   time step: 33500; t=   83.03 s ( 41.5%)
#   time step: 33600; t=   83.27 s ( 41.6%)
#   time step: 33700; t=   83.52 s ( 41.8%)
#   time step: 33800; t=   83.77 s ( 41.9%)
#   time step: 33900; t=   84.02 s ( 42.0%)
#   time step: 34000; t=   84.26 s ( 42.1%)
#   time step: 34100; t=   84.51 s ( 42.3%)
#   time step: 34200; t=   84.76 s ( 42.4%)
#   time step: 34300; t=   85.01 s ( 42.5%)
#   time step: 34400; t=   85.26 s ( 42.6%)
#   time step: 34500; t=   85.50 s ( 42.8%)
#   time step: 34600; t=   85.75 s ( 42.9%)
#   time step: 34700; t=   86.00 s ( 43.0%)
#   time step: 34800; t=   86.25 s ( 43.1%)
#   time step: 34900; t=   86.50 s ( 43.2%)
#   time step: 35000; t=   86.74 s ( 43.4%)
#   time step: 35100; t=   86.99 s ( 43.5%)
#   time step: 35200; t=   87.24 s ( 43.6%)
#   time step: 35300; t=   87.49 s ( 43.7%)
#   time step: 35400; t=   87.73 s ( 43.9%)
#   time step: 35500; t=   87.98 s ( 44.0%)
#   time step: 35600; t=   88.23 s ( 44.1%)
#   time step: 35700; t=   88.48 s ( 44.2%)
#   time step: 35800; t=   88.73 s ( 44.4%)
#   time step: 35900; t=   88.97 s ( 44.5%)
#   time step: 36000; t=   89.22 s ( 44.6%)
#   time step: 36100; t=   89.47 s ( 44.7%)
#   time step: 36200; t=   89.72 s ( 44.9%)
#   time step: 36300; t=   89.96 s ( 45.0%)
#   time step: 36400; t=   90.21 s ( 45.1%)
#   time step: 36500; t=   90.46 s ( 45.2%)
#   time step: 36600; t=   90.71 s ( 45.4%)
#   time step: 36700; t=   90.96 s ( 45.5%)
#   time step: 36800; t=   91.20 s ( 45.6%)
#   time step: 36900; t=   91.45 s ( 45.7%)
#   time step: 37000; t=   91.70 s ( 45.8%)
#   time step: 37100; t=   91.95 s ( 46.0%)
#   time step: 37200; t=   92.20 s ( 46.1%)
#   time step: 37300; t=   92.44 s ( 46.2%)
#   time step: 37400; t=   92.69 s ( 46.3%)
#   time step: 37500; t=   92.94 s ( 46.5%)
#   time step: 37600; t=   93.19 s ( 46.6%)
#   time step: 37700; t=   93.43 s ( 46.7%)
#   time step: 37800; t=   93.68 s ( 46.8%)
#   time step: 37900; t=   93.93 s ( 47.0%)
#   time step: 38000; t=   94.18 s ( 47.1%)
#   time step: 38100; t=   94.43 s ( 47.2%)
#   time step: 38200; t=   94.67 s ( 47.3%)
#   time step: 38300; t=   94.92 s ( 47.5%)
#   time step: 38400; t=   95.17 s ( 47.6%)
#   time step: 38500; t=   95.42 s ( 47.7%)
#   time step: 38600; t=   95.67 s ( 47.8%)
#   time step: 38700; t=   95.91 s ( 48.0%)
#   time step: 38800; t=   96.16 s ( 48.1%)
#   time step: 38900; t=   96.41 s ( 48.2%)
#   time step: 39000; t=   96.66 s ( 48.3%)
#   time step: 39100; t=   96.90 s ( 48.5%)
#   time step: 39200; t=   97.15 s ( 48.6%)
#   time step: 39300; t=   97.40 s ( 48.7%)
#   time step: 39400; t=   97.65 s ( 48.8%)
#   time step: 39500; t=   97.90 s ( 48.9%)
#   time step: 39600; t=   98.14 s ( 49.1%)
#   time step: 39700; t=   98.39 s ( 49.2%)
#   time step: 39800; t=   98.64 s ( 49.3%)
#   time step: 39900; t=   98.89 s ( 49.4%)
#   time step: 40000; t=   99.13 s ( 49.6%)
#   time step: 40100; t=   99.38 s ( 49.7%)
#   time step: 40200; t=   99.63 s ( 49.8%)
#   time step: 40300; t=   99.88 s ( 49.9%)
#   time step: 40400; t=  100.13 s ( 50.1%)
#   time step: 40500; t=  100.37 s ( 50.2%)
#   time step: 40600; t=  100.62 s ( 50.3%)
#   time step: 40700; t=  100.87 s ( 50.4%)
#   time step: 40800; t=  101.12 s ( 50.6%)
#   time step: 40900; t=  101.37 s ( 50.7%)
#   time step: 41000; t=  101.61 s ( 50.8%)
#   time step: 41100; t=  101.86 s ( 50.9%)
#   time step: 41200; t=  102.11 s ( 51.1%)
#   time step: 41300; t=  102.36 s ( 51.2%)
#   time step: 41400; t=  102.60 s ( 51.3%)
#   time step: 41500; t=  102.85 s ( 51.4%)
#   time step: 41600; t=  103.10 s ( 51.5%)
#   time step: 41700; t=  103.35 s ( 51.7%)
#   time step: 41800; t=  103.60 s ( 51.8%)
#   time step: 41900; t=  103.84 s ( 51.9%)
#   time step: 42000; t=  104.09 s ( 52.0%)
#   time step: 42100; t=  104.34 s ( 52.2%)
#   time step: 42200; t=  104.59 s ( 52.3%)
#   time step: 42300; t=  104.84 s ( 52.4%)
#   time step: 42400; t=  105.08 s ( 52.5%)
#   time step: 42500; t=  105.33 s ( 52.7%)
#   time step: 42600; t=  105.58 s ( 52.8%)
#   time step: 42700; t=  105.83 s ( 52.9%)
#   time step: 42800; t=  106.07 s ( 53.0%)
#   time step: 42900; t=  106.32 s ( 53.2%)
#   time step: 43000; t=  106.57 s ( 53.3%)
#   time step: 43100; t=  106.82 s ( 53.4%)
#   time step: 43200; t=  107.07 s ( 53.5%)
#   time step: 43300; t=  107.31 s ( 53.7%)
#   time step: 43400; t=  107.56 s ( 53.8%)
#   time step: 43500; t=  107.81 s ( 53.9%)
#   time step: 43600; t=  108.06 s ( 54.0%)
#   time step: 43700; t=  108.30 s ( 54.2%)
#   time step: 43800; t=  108.55 s ( 54.3%)
#   time step: 43900; t=  108.80 s ( 54.4%)
#   time step: 44000; t=  109.05 s ( 54.5%)
#   time step: 44100; t=  109.30 s ( 54.6%)
#   time step: 44200; t=  109.54 s ( 54.8%)
#   time step: 44300; t=  109.79 s ( 54.9%)
#   time step: 44400; t=  110.04 s ( 55.0%)
#   time step: 44500; t=  110.29 s ( 55.1%)
#   time step: 44600; t=  110.54 s ( 55.3%)
#   time step: 44700; t=  110.78 s ( 55.4%)
#   time step: 44800; t=  111.03 s ( 55.5%)
#   time step: 44900; t=  111.28 s ( 55.6%)
#   time step: 45000; t=  111.53 s ( 55.8%)
#   time step: 45100; t=  111.77 s ( 55.9%)
#   time step: 45200; t=  112.02 s ( 56.0%)
#   time step: 45300; t=  112.27 s ( 56.1%)
#   time step: 45400; t=  112.52 s ( 56.3%)
#   time step: 45500; t=  112.77 s ( 56.4%)
#   time step: 45600; t=  113.01 s ( 56.5%)
#   time step: 45700; t=  113.26 s ( 56.6%)
#   time step: 45800; t=  113.51 s ( 56.8%)
#   time step: 45900; t=  113.76 s ( 56.9%)
#   time step: 46000; t=  114.01 s ( 57.0%)
#   time step: 46100; t=  114.25 s ( 57.1%)
#   time step: 46200; t=  114.50 s ( 57.2%)
#   time step: 46300; t=  114.75 s ( 57.4%)
#   time step: 46400; t=  115.00 s ( 57.5%)
#   time step: 46500; t=  115.24 s ( 57.6%)
#   time step: 46600; t=  115.49 s ( 57.7%)
#   time step: 46700; t=  115.74 s ( 57.9%)
#   time step: 46800; t=  115.99 s ( 58.0%)
#   time step: 46900; t=  116.24 s ( 58.1%)
#   time step: 47000; t=  116.48 s ( 58.2%)
#   time step: 47100; t=  116.73 s ( 58.4%)
#   time step: 47200; t=  116.98 s ( 58.5%)
#   time step: 47300; t=  117.23 s ( 58.6%)
#   time step: 47400; t=  117.47 s ( 58.7%)
#   time step: 47500; t=  117.72 s ( 58.9%)
#   time step: 47600; t=  117.97 s ( 59.0%)
#   time step: 47700; t=  118.22 s ( 59.1%)
#   time step: 47800; t=  118.47 s ( 59.2%)
#   time step: 47900; t=  118.71 s ( 59.4%)
#   time step: 48000; t=  118.96 s ( 59.5%)
#   time step: 48100; t=  119.21 s ( 59.6%)
#   time step: 48200; t=  119.46 s ( 59.7%)
#   time step: 48300; t=  119.71 s ( 59.9%)
#   time step: 48400; t=  119.95 s ( 60.0%)
#   time step: 48500; t=  120.20 s ( 60.1%)
#   time step: 48600; t=  120.45 s ( 60.2%)
#   time step: 48700; t=  120.70 s ( 60.3%)
#   time step: 48800; t=  120.94 s ( 60.5%)
#   time step: 48900; t=  121.19 s ( 60.6%)
#   time step: 49000; t=  121.44 s ( 60.7%)
#   time step: 49100; t=  121.69 s ( 60.8%)
#   time step: 49200; t=  121.94 s ( 61.0%)
#   time step: 49300; t=  122.18 s ( 61.1%)
#   time step: 49400; t=  122.43 s ( 61.2%)
#   time step: 49500; t=  122.68 s ( 61.3%)
#   time step: 49600; t=  122.93 s ( 61.5%)
#   time step: 49700; t=  123.17 s ( 61.6%)
#   time step: 49800; t=  123.42 s ( 61.7%)
#   time step: 49900; t=  123.67 s ( 61.8%)
#   time step: 50000; t=  123.92 s ( 62.0%)
#   time step: 50100; t=  124.17 s ( 62.1%)
#   time step: 50200; t=  124.41 s ( 62.2%)
#   time step: 50300; t=  124.66 s ( 62.3%)
#   time step: 50400; t=  124.91 s ( 62.5%)
#   time step: 50500; t=  125.16 s ( 62.6%)
#   time step: 50600; t=  125.41 s ( 62.7%)
#   time step: 50700; t=  125.65 s ( 62.8%)
#   time step: 50800; t=  125.90 s ( 62.9%)
#   time step: 50900; t=  126.15 s ( 63.1%)
#   time step: 51000; t=  126.40 s ( 63.2%)
#   time step: 51100; t=  126.64 s ( 63.3%)
#   time step: 51200; t=  126.89 s ( 63.4%)
#   time step: 51300; t=  127.14 s ( 63.6%)
#   time step: 51400; t=  127.39 s ( 63.7%)
#   time step: 51500; t=  127.64 s ( 63.8%)
#   time step: 51600; t=  127.88 s ( 63.9%)
#   time step: 51700; t=  128.13 s ( 64.1%)
#   time step: 51800; t=  128.38 s ( 64.2%)
#   time step: 51900; t=  128.63 s ( 64.3%)
#   time step: 52000; t=  128.88 s ( 64.4%)
#   time step: 52100; t=  129.12 s ( 64.6%)
#   time step: 52200; t=  129.37 s ( 64.7%)
#   time step: 52300; t=  129.62 s ( 64.8%)
#   time step: 52400; t=  129.87 s ( 64.9%)
#   time step: 52500; t=  130.11 s ( 65.1%)
#   time step: 52600; t=  130.36 s ( 65.2%)
#   time step: 52700; t=  130.61 s ( 65.3%)
#   time step: 52800; t=  130.86 s ( 65.4%)
#   time step: 52900; t=  131.11 s ( 65.6%)
#   time step: 53000; t=  131.35 s ( 65.7%)
#   time step: 53100; t=  131.60 s ( 65.8%)
#   time step: 53200; t=  131.85 s ( 65.9%)
#   time step: 53300; t=  132.10 s ( 66.0%)
#   time step: 53400; t=  132.34 s ( 66.2%)
#   time step: 53500; t=  132.59 s ( 66.3%)
#   time step: 53600; t=  132.84 s ( 66.4%)
#   time step: 53700; t=  133.09 s ( 66.5%)
#   time step: 53800; t=  133.34 s ( 66.7%)
#   time step: 53900; t=  133.58 s ( 66.8%)
#   time step: 54000; t=  133.83 s ( 66.9%)
#   time step: 54100; t=  134.08 s ( 67.0%)
#   time step: 54200; t=  134.33 s ( 67.2%)
#   time step: 54300; t=  134.58 s ( 67.3%)
#   time step: 54400; t=  134.82 s ( 67.4%)
#   time step: 54500; t=  135.07 s ( 67.5%)
#   time step: 54600; t=  135.32 s ( 67.7%)
#   time step: 54700; t=  135.57 s ( 67.8%)
#   time step: 54800; t=  135.81 s ( 67.9%)
#   time step: 54900; t=  136.06 s ( 68.0%)
#   time step: 55000; t=  136.31 s ( 68.2%)
#   time step: 55100; t=  136.56 s ( 68.3%)
#   time step: 55200; t=  136.81 s ( 68.4%)
#   time step: 55300; t=  137.05 s ( 68.5%)
#   time step: 55400; t=  137.30 s ( 68.7%)
#   time step: 55500; t=  137.55 s ( 68.8%)
#   time step: 55600; t=  137.80 s ( 68.9%)
#   time step: 55700; t=  138.05 s ( 69.0%)
#   time step: 55800; t=  138.29 s ( 69.1%)
#   time step: 55900; t=  138.54 s ( 69.3%)
#   time step: 56000; t=  138.79 s ( 69.4%)
#   time step: 56100; t=  139.04 s ( 69.5%)
#   time step: 56200; t=  139.28 s ( 69.6%)
#   time step: 56300; t=  139.53 s ( 69.8%)
#   time step: 56400; t=  139.78 s ( 69.9%)
#   time step: 56500; t=  140.03 s ( 70.0%)
#   time step: 56600; t=  140.28 s ( 70.1%)
#   time step: 56700; t=  140.52 s ( 70.3%)
#   time step: 56800; t=  140.77 s ( 70.4%)
#   time step: 56900; t=  141.02 s ( 70.5%)
#   time step: 57000; t=  141.27 s ( 70.6%)
#   time step: 57100; t=  141.51 s ( 70.8%)
#   time step: 57200; t=  141.76 s ( 70.9%)
#   time step: 57300; t=  142.01 s ( 71.0%)
#   time step: 57400; t=  142.26 s ( 71.1%)
#   time step: 57500; t=  142.51 s ( 71.3%)
#   time step: 57600; t=  142.75 s ( 71.4%)
#   time step: 57700; t=  143.00 s ( 71.5%)
#   time step: 57800; t=  143.25 s ( 71.6%)
#   time step: 57900; t=  143.50 s ( 71.7%)
#   time step: 58000; t=  143.75 s ( 71.9%)
#   time step: 58100; t=  143.99 s ( 72.0%)
#   time step: 58200; t=  144.24 s ( 72.1%)
#   time step: 58300; t=  144.49 s ( 72.2%)
#   time step: 58400; t=  144.74 s ( 72.4%)
#   time step: 58500; t=  144.98 s ( 72.5%)
#   time step: 58600; t=  145.23 s ( 72.6%)
#   time step: 58700; t=  145.48 s ( 72.7%)
#   time step: 58800; t=  145.73 s ( 72.9%)
#   time step: 58900; t=  145.98 s ( 73.0%)
#   time step: 59000; t=  146.22 s ( 73.1%)
#   time step: 59100; t=  146.47 s ( 73.2%)
#   time step: 59200; t=  146.72 s ( 73.4%)
#   time step: 59300; t=  146.97 s ( 73.5%)
#   time step: 59400; t=  147.22 s ( 73.6%)
#   time step: 59500; t=  147.46 s ( 73.7%)
#   time step: 59600; t=  147.71 s ( 73.9%)
#   time step: 59700; t=  147.96 s ( 74.0%)
#   time step: 59800; t=  148.21 s ( 74.1%)
#   time step: 59900; t=  148.45 s ( 74.2%)
#   time step: 60000; t=  148.70 s ( 74.4%)
#   time step: 60100; t=  148.95 s ( 74.5%)
#   time step: 60200; t=  149.20 s ( 74.6%)
#   time step: 60300; t=  149.45 s ( 74.7%)
#   time step: 60400; t=  149.69 s ( 74.8%)
#   time step: 60500; t=  149.94 s ( 75.0%)
#   time step: 60600; t=  150.19 s ( 75.1%)
#   time step: 60700; t=  150.44 s ( 75.2%)
#   time step: 60800; t=  150.68 s ( 75.3%)
#   time step: 60900; t=  150.93 s ( 75.5%)
#   time step: 61000; t=  151.18 s ( 75.6%)
#   time step: 61100; t=  151.43 s ( 75.7%)
#   time step: 61200; t=  151.68 s ( 75.8%)
#   time step: 61300; t=  151.92 s ( 76.0%)
#   time step: 61400; t=  152.17 s ( 76.1%)
#   time step: 61500; t=  152.42 s ( 76.2%)
#   time step: 61600; t=  152.67 s ( 76.3%)
#   time step: 61700; t=  152.92 s ( 76.5%)
#   time step: 61800; t=  153.16 s ( 76.6%)
#   time step: 61900; t=  153.41 s ( 76.7%)
#   time step: 62000; t=  153.66 s ( 76.8%)
#   time step: 62100; t=  153.91 s ( 77.0%)
#   time step: 62200; t=  154.15 s ( 77.1%)
#   time step: 62300; t=  154.40 s ( 77.2%)
#   time step: 62400; t=  154.65 s ( 77.3%)
#   time step: 62500; t=  154.90 s ( 77.4%)
#   time step: 62600; t=  155.15 s ( 77.6%)
#   time step: 62700; t=  155.39 s ( 77.7%)
#   time step: 62800; t=  155.64 s ( 77.8%)
#   time step: 62900; t=  155.89 s ( 77.9%)
#   time step: 63000; t=  156.14 s ( 78.1%)
#   time step: 63100; t=  156.39 s ( 78.2%)
#   time step: 63200; t=  156.63 s ( 78.3%)
#   time step: 63300; t=  156.88 s ( 78.4%)
#   time step: 63400; t=  157.13 s ( 78.6%)
#   time step: 63500; t=  157.38 s ( 78.7%)
#   time step: 63600; t=  157.62 s ( 78.8%)
#   time step: 63700; t=  157.87 s ( 78.9%)
#   time step: 63800; t=  158.12 s ( 79.1%)
#   time step: 63900; t=  158.37 s ( 79.2%)
#   time step: 64000; t=  158.62 s ( 79.3%)
#   time step: 64100; t=  158.86 s ( 79.4%)
#   time step: 64200; t=  159.11 s ( 79.6%)
#   time step: 64300; t=  159.36 s ( 79.7%)
#   time step: 64400; t=  159.61 s ( 79.8%)
#   time step: 64500; t=  159.85 s ( 79.9%)
#   time step: 64600; t=  160.10 s ( 80.1%)
#   time step: 64700; t=  160.35 s ( 80.2%)
#   time step: 64800; t=  160.60 s ( 80.3%)
#   time step: 64900; t=  160.85 s ( 80.4%)
#   time step: 65000; t=  161.09 s ( 80.5%)
#   time step: 65100; t=  161.34 s ( 80.7%)
#   time step: 65200; t=  161.59 s ( 80.8%)
#   time step: 65300; t=  161.84 s ( 80.9%)
#   time step: 65400; t=  162.09 s ( 81.0%)
#   time step: 65500; t=  162.33 s ( 81.2%)
#   time step: 65600; t=  162.58 s ( 81.3%)
#   time step: 65700; t=  162.83 s ( 81.4%)
#   time step: 65800; t=  163.08 s ( 81.5%)
#   time step: 65900; t=  163.32 s ( 81.7%)
#   time step: 66000; t=  163.57 s ( 81.8%)
#   time step: 66100; t=  163.82 s ( 81.9%)
#   time step: 66200; t=  164.07 s ( 82.0%)
#   time step: 66300; t=  164.32 s ( 82.2%)
#   time step: 66400; t=  164.56 s ( 82.3%)
#   time step: 66500; t=  164.81 s ( 82.4%)
#   time step: 66600; t=  165.06 s ( 82.5%)
#   time step: 66700; t=  165.31 s ( 82.7%)
#   time step: 66800; t=  165.56 s ( 82.8%)
#   time step: 66900; t=  165.80 s ( 82.9%)
#   time step: 67000; t=  166.05 s ( 83.0%)
#   time step: 67100; t=  166.30 s ( 83.1%)
#   time step: 67200; t=  166.55 s ( 83.3%)
#   time step: 67300; t=  166.79 s ( 83.4%)
#   time step: 67400; t=  167.04 s ( 83.5%)
#   time step: 67500; t=  167.29 s ( 83.6%)
#   time step: 67600; t=  167.54 s ( 83.8%)
#   time step: 67700; t=  167.79 s ( 83.9%)
#   time step: 67800; t=  168.03 s ( 84.0%)
#   time step: 67900; t=  168.28 s ( 84.1%)
#   time step: 68000; t=  168.53 s ( 84.3%)
#   time step: 68100; t=  168.78 s ( 84.4%)
#   time step: 68200; t=  169.02 s ( 84.5%)
#   time step: 68300; t=  169.27 s ( 84.6%)
#   time step: 68400; t=  169.52 s ( 84.8%)
#   time step: 68500; t=  169.77 s ( 84.9%)
#   time step: 68600; t=  170.02 s ( 85.0%)
#   time step: 68700; t=  170.26 s ( 85.1%)
#   time step: 68800; t=  170.51 s ( 85.3%)
#   time step: 68900; t=  170.76 s ( 85.4%)
#   time step: 69000; t=  171.01 s ( 85.5%)
#   time step: 69100; t=  171.26 s ( 85.6%)
#   time step: 69200; t=  171.50 s ( 85.8%)
#   time step: 69300; t=  171.75 s ( 85.9%)
#   time step: 69400; t=  172.00 s ( 86.0%)
#   time step: 69500; t=  172.25 s ( 86.1%)
#   time step: 69600; t=  172.49 s ( 86.2%)
#   time step: 69700; t=  172.74 s ( 86.4%)
#   time step: 69800; t=  172.99 s ( 86.5%)
#   time step: 69900; t=  173.24 s ( 86.6%)
#   time step: 70000; t=  173.49 s ( 86.7%)
#   time step: 70100; t=  173.73 s ( 86.9%)
#   time step: 70200; t=  173.98 s ( 87.0%)
#   time step: 70300; t=  174.23 s ( 87.1%)
#   time step: 70400; t=  174.48 s ( 87.2%)
#   time step: 70500; t=  174.73 s ( 87.4%)
#   time step: 70600; t=  174.97 s ( 87.5%)
#   time step: 70700; t=  175.22 s ( 87.6%)
#   time step: 70800; t=  175.47 s ( 87.7%)
#   time step: 70900; t=  175.72 s ( 87.9%)
#   time step: 71000; t=  175.96 s ( 88.0%)
#   time step: 71100; t=  176.21 s ( 88.1%)
#   time step: 71200; t=  176.46 s ( 88.2%)
#   time step: 71300; t=  176.71 s ( 88.4%)
#   time step: 71400; t=  176.96 s ( 88.5%)
#   time step: 71500; t=  177.20 s ( 88.6%)
#   time step: 71600; t=  177.45 s ( 88.7%)
#   time step: 71700; t=  177.70 s ( 88.8%)
#   time step: 71800; t=  177.95 s ( 89.0%)
#   time step: 71900; t=  178.19 s ( 89.1%)
#   time step: 72000; t=  178.44 s ( 89.2%)
#   time step: 72100; t=  178.69 s ( 89.3%)
#   time step: 72200; t=  178.94 s ( 89.5%)
#   time step: 72300; t=  179.19 s ( 89.6%)
#   time step: 72400; t=  179.43 s ( 89.7%)
#   time step: 72500; t=  179.68 s ( 89.8%)
#   time step: 72600; t=  179.93 s ( 90.0%)
#   time step: 72700; t=  180.18 s ( 90.1%)
#   time step: 72800; t=  180.43 s ( 90.2%)
#   time step: 72900; t=  180.67 s ( 90.3%)
#   time step: 73000; t=  180.92 s ( 90.5%)
#   time step: 73100; t=  181.17 s ( 90.6%)
#   time step: 73200; t=  181.42 s ( 90.7%)
#   time step: 73300; t=  181.66 s ( 90.8%)
#   time step: 73400; t=  181.91 s ( 91.0%)
#   time step: 73500; t=  182.16 s ( 91.1%)
#   time step: 73600; t=  182.41 s ( 91.2%)
#   time step: 73700; t=  182.66 s ( 91.3%)
#   time step: 73800; t=  182.90 s ( 91.5%)
#   time step: 73900; t=  183.15 s ( 91.6%)
#   time step: 74000; t=  183.40 s ( 91.7%)
#   time step: 74100; t=  183.65 s ( 91.8%)
#   time step: 74200; t=  183.90 s ( 91.9%)
#   time step: 74300; t=  184.14 s ( 92.1%)
#   time step: 74400; t=  184.39 s ( 92.2%)
#   time step: 74500; t=  184.64 s ( 92.3%)
#   time step: 74600; t=  184.89 s ( 92.4%)
#   time step: 74700; t=  185.13 s ( 92.6%)
#   time step: 74800; t=  185.38 s ( 92.7%)
#   time step: 74900; t=  185.63 s ( 92.8%)
#   time step: 75000; t=  185.88 s ( 92.9%)
#   time step: 75100; t=  186.13 s ( 93.1%)
#   time step: 75200; t=  186.37 s ( 93.2%)
#   time step: 75300; t=  186.62 s ( 93.3%)
#   time step: 75400; t=  186.87 s ( 93.4%)
#   time step: 75500; t=  187.12 s ( 93.6%)
#   time step: 75600; t=  187.36 s ( 93.7%)
#   time step: 75700; t=  187.61 s ( 93.8%)
#   time step: 75800; t=  187.86 s ( 93.9%)
#   time step: 75900; t=  188.11 s ( 94.1%)
#   time step: 76000; t=  188.36 s ( 94.2%)
#   time step: 76100; t=  188.60 s ( 94.3%)
#   time step: 76200; t=  188.85 s ( 94.4%)
#   time step: 76300; t=  189.10 s ( 94.5%)
#   time step: 76400; t=  189.35 s ( 94.7%)
#   time step: 76500; t=  189.60 s ( 94.8%)
#   time step: 76600; t=  189.84 s ( 94.9%)
#   time step: 76700; t=  190.09 s ( 95.0%)
#   time step: 76800; t=  190.34 s ( 95.2%)
#   time step: 76900; t=  190.59 s ( 95.3%)
#   time step: 77000; t=  190.83 s ( 95.4%)
#   time step: 77100; t=  191.08 s ( 95.5%)
#   time step: 77200; t=  191.33 s ( 95.7%)
#   time step: 77300; t=  191.58 s ( 95.8%)
#   time step: 77400; t=  191.83 s ( 95.9%)
#   time step: 77500; t=  192.07 s ( 96.0%)
#   time step: 77600; t=  192.32 s ( 96.2%)
#   time step: 77700; t=  192.57 s ( 96.3%)
#   time step: 77800; t=  192.82 s ( 96.4%)
#   time step: 77900; t=  193.07 s ( 96.5%)
#   time step: 78000; t=  193.31 s ( 96.7%)
#   time step: 78100; t=  193.56 s ( 96.8%)
#   time step: 78200; t=  193.81 s ( 96.9%)
#   time step: 78300; t=  194.06 s ( 97.0%)
#   time step: 78400; t=  194.30 s ( 97.2%)
#   time step: 78500; t=  194.55 s ( 97.3%)
#   time step: 78600; t=  194.80 s ( 97.4%)
#   time step: 78700; t=  195.05 s ( 97.5%)
#   time step: 78800; t=  195.30 s ( 97.6%)
#   time step: 78900; t=  195.54 s ( 97.8%)
#   time step: 79000; t=  195.79 s ( 97.9%)
#   time step: 79100; t=  196.04 s ( 98.0%)
#   time step: 79200; t=  196.29 s ( 98.1%)
#   time step: 79300; t=  196.53 s ( 98.3%)
#   time step: 79400; t=  196.78 s ( 98.4%)
#   time step: 79500; t=  197.03 s ( 98.5%)
#   time step: 79600; t=  197.28 s ( 98.6%)
#   time step: 79700; t=  197.53 s ( 98.8%)
#   time step: 79800; t=  197.77 s ( 98.9%)
#   time step: 79900; t=  198.02 s ( 99.0%)
#   time step: 80000; t=  198.27 s ( 99.1%)
#   time step: 80100; t=  198.52 s ( 99.3%)
#   time step: 80200; t=  198.77 s ( 99.4%)
#   time step: 80300; t=  199.01 s ( 99.5%)
#   time step: 80400; t=  199.26 s ( 99.6%)
#   time step: 80500; t=  199.51 s ( 99.8%)
#   time step: 80600; t=  199.76 s ( 99.9%)
#
#           Summary of timing measurements:
#
#                                            calls        t_call       t_total t_frac
# CLOCKS: Time loop routine                      1  51741.046458  51741.046458  0.999
# CLOCKS: Assembly/MPI routines             322796      0.084078  27139.901289  0.524
# CLOCKS: Stiffness routine                 161398      0.104595  16881.382802  0.326
# CLOCKS: Dump routine                       80700      0.000047      3.827000  0.000
# CLOCKS: Total measured time:   51814.360461
#
#  =========PROGRAM axisem FINISHED=============

# %% [markdown]
# The next cell runs post-processing on solver output

# %%
# %%bash -s "$SOLVER" "$run_name"
# cd $1/UTILS
# make all
# cd $1/$2
# ./post_processing.csh
# Out:
# make: Nothing to be done for `all'.
#
#
# >>>>>>>>> AXISEM POST PROCESSING <<<<<<<<<
#
#
# All post-processed data in: ./Data_Postprocessing
# Homedir: /Users/katdapre/Documents/Synthetics/axisem-9f0be2f/SOLVER/github_2Hz_test13 simdir1: ./
#
# %%%%%%%%% PROCESSING seismograms/wavefields %%%%%%%%%
# .... output in ./Data_Postprocessing/OUTPUT_postprocessing ....
# xpost_processing exited with error
# check output for details:
# ./Data_Postprocessing/OUTPUT_postprocessing
# At line 349 of file post_processing.F90 (unit = 60, file = './/Data/recfile_0001_disp.dat')
# Fortran runtime error: End of file
#
# Error termination. Backtrace:
# #0  0x10d8ca4dc
# #1  0x10d8cb395
# #2  0x10d8cbf55
# #3  0x10de44de3
# #4  0x10de3b73e
# #5  0x10de3c9b0
# #6  0x10de430c2
# #7  0x10d193de7
# #8  0x10d197aee
